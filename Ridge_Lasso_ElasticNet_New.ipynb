# %%
#in built dataset from sklearn is used
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
# fillna(): replaces na with mean mode or median from single column at a time.
# SimpleImputer will replace na from multiple columns at a time
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
# We have seen OHE: for x variables, Lable Encoding: for y variable
# OrdinalEncoder: works same as Lable Encoder but on x variables
#from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/cars_new.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %% [markdown]
# EDA

# %%
df.info()
# ? is missing value because of it datatype has become object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 24.1+ KB

# %%
df.isna().sum() # not identified ? as missing value
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df['normalized-losses'].value_counts()
# Out:
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64

# %%
df[df['horsepower']=='?']
# Out:
#      symboling normalized-losses     make fuel-type body-style drive-wheels  \
# 130          0                 ?  renault       gas      wagon          fwd
# 131          2                 ?  renault       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 130           front   66.5    55.2         ohc          132          ?
# 131           front   66.6    50.5         ohc          132          ?
#
#      city-mpg  highway-mpg  price
# 130        23           31   9295
# 131        23           31   9895

# %%
df.replace('?',np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.dtypes # still normalized-losses is object, We have replaced ? with Nan with replace()
# to change data type we have to use astype()
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df['normalized-losses']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
si = SimpleImputer(strategy='median')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.iloc[:,[1,11]]
# Out:
#     normalized-losses horsepower
# 0                 NaN        111
# 1                 NaN        111
# 2                 NaN        154
# 3                 164        102
# 4                 164        115
# ..                ...        ...
# 200                95        114
# 201                95        160
# 202                95        134
# 203                95        106
# 204                95        114
#
# [205 rows x 2 columns]

# %%
# OR
df.loc[:,['normalized-losses','horsepower']]
# Out:
#     normalized-losses horsepower
# 0                 NaN        111
# 1                 NaN        111
# 2                 NaN        154
# 3                 164        102
# 4                 164        115
# ..                ...        ...
# 200                95        114
# 201                95        160
# 202                95        134
# 203                95        106
# 204                95        114
#
# [205 rows x 2 columns]

# %%
df.iloc[:,[1,11]] = si.fit_transform(df.iloc[:,[1,11]])
# fit will calculate median of col 1 and 11, transform: replace missing value by median

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3             115.0  alfa-romero       gas  convertible
# 1            3             115.0  alfa-romero       gas  convertible
# 2            1             115.0  alfa-romero       gas    hatchback
# 3            2             164.0         audi       gas        sedan
# 4            2             164.0         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1              95.0        volvo       gas        sedan
# 201         -1              95.0        volvo       gas        sedan
# 202         -1              95.0        volvo       gas        sedan
# 203         -1              95.0        volvo    diesel        sedan
# 204         -1              95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0        111.0        21           27  13495
# 1        111.0        21           27  16500
# 2        154.0        19           26  16500
# 3        102.0        24           30  13950
# 4        115.0        18           22  17450
# ..         ...       ...          ...    ...
# 200      114.0        23           28  16845
# 201      160.0        19           25  19045
# 202      134.0        18           23  21485
# 203      106.0        26           27  22470
# 204      114.0        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.select_dtypes(int) # will display only colums of int data type, try float
# Out:
#      symboling  engine-size  city-mpg  highway-mpg  price
# 0            3          130        21           27  13495
# 1            3          130        21           27  16500
# 2            1          152        19           26  16500
# 3            2          109        24           30  13950
# 4            2          136        18           22  17450
# ..         ...          ...       ...          ...    ...
# 200         -1          141        23           28  16845
# 201         -1          141        19           25  19045
# 202         -1          173        18           23  21485
# 203         -1          145        26           27  22470
# 204         -1          141        19           25  22625
#
# [205 rows x 5 columns]

# %%
df.select_dtypes(float)
# Out:
#      width  height
# 0     64.1    48.8
# 1     64.1    48.8
# 2     65.5    52.4
# 3     66.2    54.3
# 4     66.4    54.3
# ..     ...     ...
# 200   68.9    55.5
# 201   68.8    55.5
# 202   68.9    55.5
# 203   68.9    55.5
# 204   68.9    55.5
#
# [205 rows x 2 columns]

# %%
df.select_dtypes(object)
# Out:
#     normalized-losses         make fuel-type   body-style drive-wheels  \
# 0               115.0  alfa-romero       gas  convertible          rwd
# 1               115.0  alfa-romero       gas  convertible          rwd
# 2               115.0  alfa-romero       gas    hatchback          rwd
# 3               164.0         audi       gas        sedan          fwd
# 4               164.0         audi       gas        sedan          4wd
# ..                ...          ...       ...          ...          ...
# 200              95.0        volvo       gas        sedan          rwd
# 201              95.0        volvo       gas        sedan          rwd
# 202              95.0        volvo       gas        sedan          rwd
# 203              95.0        volvo    diesel        sedan          rwd
# 204              95.0        volvo       gas        sedan          rwd
#
#     engine-location engine-type horsepower
# 0             front        dohc      111.0
# 1             front        dohc      111.0
# 2             front        ohcv      154.0
# 3             front         ohc      102.0
# 4             front         ohc      115.0
# ..              ...         ...        ...
# 200           front         ohc      114.0
# 201           front         ohc      160.0
# 202           front        ohcv      134.0
# 203           front         ohc      106.0
# 204           front         ohc      114.0
#
# [205 rows x 8 columns]

# %%
df.select_dtypes([int,float]) # all numerical columns
# Out:
#      symboling  width  height  engine-size  city-mpg  highway-mpg  price
# 0            3   64.1    48.8          130        21           27  13495
# 1            3   64.1    48.8          130        21           27  16500
# 2            1   65.5    52.4          152        19           26  16500
# 3            2   66.2    54.3          109        24           30  13950
# 4            2   66.4    54.3          136        18           22  17450
# ..         ...    ...     ...          ...       ...          ...    ...
# 200         -1   68.9    55.5          141        23           28  16845
# 201         -1   68.8    55.5          141        19           25  19045
# 202         -1   68.9    55.5          173        18           23  21485
# 203         -1   68.9    55.5          145        26           27  22470
# 204         -1   68.9    55.5          141        19           25  22625
#
# [205 rows x 7 columns]

# %%
# Encoding: selecting only categorical columns
cat_cols = df.select_dtypes(object).columns # store col names in cat_cols variable
cat_cols
# Out:
# Index(['normalized-losses', 'make', 'fuel-type', 'body-style', 'drive-wheels',
#        'engine-location', 'engine-type', 'horsepower'],
#       dtype='object')

# %%
df[cat_cols] # extract values of all col names from cat_cols
# Out:
#     normalized-losses         make fuel-type   body-style drive-wheels  \
# 0               115.0  alfa-romero       gas  convertible          rwd
# 1               115.0  alfa-romero       gas  convertible          rwd
# 2               115.0  alfa-romero       gas    hatchback          rwd
# 3               164.0         audi       gas        sedan          fwd
# 4               164.0         audi       gas        sedan          4wd
# ..                ...          ...       ...          ...          ...
# 200              95.0        volvo       gas        sedan          rwd
# 201              95.0        volvo       gas        sedan          rwd
# 202              95.0        volvo       gas        sedan          rwd
# 203              95.0        volvo    diesel        sedan          rwd
# 204              95.0        volvo       gas        sedan          rwd
#
#     engine-location engine-type horsepower
# 0             front        dohc      111.0
# 1             front        dohc      111.0
# 2             front        ohcv      154.0
# 3             front         ohc      102.0
# 4             front         ohc      115.0
# ..              ...         ...        ...
# 200           front         ohc      114.0
# 201           front         ohc      160.0
# 202           front        ohcv      134.0
# 203           front         ohc      106.0
# 204           front         ohc      114.0
#
# [205 rows x 8 columns]

# %%
oe = OrdinalEncoder() # convert categorical values to numerical
df[cat_cols] = oe.fit_transform(df[cat_cols])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3               24.0   0.0        1.0         0.0           2.0
# 1            3               24.0   0.0        1.0         0.0           2.0
# 2            1               24.0   0.0        1.0         2.0           2.0
# 3            2               42.0   1.0        1.0         3.0           1.0
# 4            2               42.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               13.0  21.0        1.0         3.0           2.0
# 201         -1               13.0  21.0        1.0         3.0           2.0
# 202         -1               13.0  21.0        1.0         3.0           2.0
# 203         -1               13.0  21.0        0.0         3.0           2.0
# 204         -1               13.0  21.0        1.0         3.0           2.0
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                0.0   64.1    48.8          0.0          130        30.0
# 1                0.0   64.1    48.8          0.0          130        30.0
# 2                0.0   65.5    52.4          5.0          152        45.0
# 3                0.0   66.2    54.3          3.0          109        27.0
# 4                0.0   66.4    54.3          3.0          136        33.0
# ..               ...    ...     ...          ...          ...         ...
# 200              0.0   68.9    55.5          3.0          141        32.0
# 201              0.0   68.8    55.5          3.0          141        48.0
# 202              0.0   68.9    55.5          5.0          173        38.0
# 203              0.0   68.9    55.5          3.0          145        28.0
# 204              0.0   68.9    55.5          3.0          141        32.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 15 columns]

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                 float64
# fuel-type            float64
# body-style           float64
# drive-wheels         float64
# engine-location      float64
# width                float64
# height               float64
# engine-type          float64
# engine-size            int64
# horsepower           float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# # **Model Building**

# %%
x = df.iloc[:,:-1]
y = df['price']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
# Linear Regression Model
lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)
ypred
# Out:
# array([ 5609.95702589,  6754.17072547,  4931.98458075,  7121.73417682,
#         9402.09908736, 26547.60607975,  7097.29375655,  2114.12478623,
#         4980.93180266, 13091.02689195, 15416.63174863, 14507.04146875,
#        16687.33234497, 11102.19643974, 16886.03396447, 13904.98490735,
#         6748.63385847,  9041.96552188, 11908.17994745,  8218.63005188,
#        11159.39349638,  6864.00544393, 13577.11112949,  6580.29253773,
#        13729.01841485,  9041.96552188, 15458.52996571,  6651.72206332,
#         4164.93835995,  9505.91887239,  7349.04016416, 14320.66970968,
#        26117.08879634, 11484.43880144, 19472.8013438 ,  6521.19613821,
#         8405.01586008, 29788.54088333, 10558.50557465, 16391.98304884,
#         6615.05117515, 20320.58064592,  8512.84364154,  8482.99796048,
#         8632.222131  ,  6914.83338254, 39886.65357936,  7507.72496121,
#        17268.83514978, 19555.29019928, 26330.34115017, 15961.10753234,
#        21898.89482028,  5692.09319643, 12555.47236386,  8029.52533205,
#        10946.98438279, 11373.15431651, 22485.6758236 ,  7525.00665666,
#         9432.77980356, 11197.10795919])

# %%
lr.intercept_ # y intercept i.e. c value
# Out:
# -67077.14022645152

# %%
lr.coef_ # slope or coefficient or weight
# Out:
# array([ 1.12546196e+02, -8.15787032e+00, -2.16748653e+02, -9.27078216e+02,
#        -1.75966492e+02,  1.78141285e+03,  1.51530341e+04,  7.30020455e+02,
#         4.26090069e+02,  3.77507844e+02,  8.76559822e+01,  5.06607528e+01,
#         4.09423838e+02, -4.28281069e+02])

# %%
lr.score(xtrain,ytrain),lr.score(xtest,ytest) # Train accuracy, Test accuracy
# overfitted model as high train accuracy and low test accuracy
# Out:
# (0.8513570943341142, 0.8058389218113039)

# %% [markdown]
# # **Lasso (L1) Regression**

# %%
# after lasso, train accuracy will decrease but test accuracy will increase
l1 = Lasso() # alpha = 0.1 by default
l1.fit(xtrain,ytrain)
l1.score(xtrain,ytrain),l1.score(xtest,ytest)
# we got same accuracy and overfitted model
# Out:
# (0.8513557681485533, 0.8059915908051956)

# %%
l1.coef_
# same as previous results: no coefficient is 0 so go for hyperparameter tuning of alpha
# Out:
# array([ 1.12276505e+02, -8.15042656e+00, -2.16548046e+02, -9.17836631e+02,
#        -1.76834795e+02,  1.77779129e+03,  1.50862651e+04,  7.28240786e+02,
#         4.26482604e+02,  3.77483028e+02,  8.77737412e+01,  5.08969372e+01,
#         4.08125298e+02, -4.26704686e+02])

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
for i in range(100,200): # try 50 to 100, 100 to 200
  l1 = Lasso(alpha = i)
  l1.fit(xtrain,ytrain)
  print(f"Alpha: {i} Train: {l1.score(xtrain,ytrain)} Test: {l1.score(xtest,ytest)}")
# Out:
# Alpha: 100 Train: 0.83810658151796 Test: 0.8155482040961651
# Alpha: 101 Train: 0.8378536264285207 Test: 0.8156028606345713
# Alpha: 102 Train: 0.8375991318080478 Test: 0.8156574468510343
# Alpha: 103 Train: 0.837341954725051 Test: 0.8157114340310523
# Alpha: 104 Train: 0.8370824100913479 Test: 0.8157642891994021
# Alpha: 105 Train: 0.8368201949832168 Test: 0.8158165171277506
# Alpha: 106 Train: 0.8365556261450315 Test: 0.8158675955702398
# Alpha: 107 Train: 0.8362885471777032 Test: 0.8159177836717547
# Alpha: 108 Train: 0.8360189588082779 Test: 0.8159670801180758
# Alpha: 109 Train: 0.8357466955371282 Test: 0.8160157431975916
# Alpha: 110 Train: 0.8354720895227603 Test: 0.8160632511732069
# Alpha: 111 Train: 0.8351949750787396 Test: 0.8161098657617744
# Alpha: 112 Train: 0.8349153524637163 Test: 0.8161555865155861
# Alpha: 113 Train: 0.8346330454330495 Test: 0.8162006760170105
# Alpha: 114 Train: 0.8343484062901871 Test: 0.816244606256736
# Alpha: 115 Train: 0.834061259152576 Test: 0.8162876423278642
# Alpha: 116 Train: 0.8337714170123772 Test: 0.8163300534585411
l1 = Lasso(alpha = 175) # select any value where train and test accuracy is same
l1.fit(xtrain,ytrain)
l1.score(xtrain,ytrain),l1.score(xtest,ytest)
# Out:
# (0.8122382107817381, 0.8172363917584536)

# %%
l1.coef_ # check columns whose slope is 0. They are not important in model building
# normalized-losses, fuel-type are not important
# Out:
# array([  61.12633958,   -6.10831648, -183.28132469,   -0.        ,
#        -336.11422228, 1064.33077389, 3274.63035983,  373.43118015,
#         486.96449759,  381.29935372,  107.65669146,   96.20510161,
#         156.01843557, -141.45741138])

# %%
xtrain.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %% [markdown]
# # **Ridge (L2) Regression**

# %%
l2 = Ridge()
l2.fit(xtrain,ytrain)
l2.score(xtrain,ytrain),l1.score(xtest,ytest)
# Out:
# (0.8456303030401331, 0.8172363917584536)

# %%
for i in range(1,100):
  l2 = Ridge(alpha = i)
  l2.fit(xtrain,ytrain)
  print(f"Alpha: {i} Train: {l2.score(xtrain,ytrain)} Test: {l2.score(xtest,ytest)}")
  # alpha = 6 to 10 same train and test accuracies
# Out:
# Alpha: 1 Train: 0.8456303030401331 Test: 0.8129412653117356
# Alpha: 2 Train: 0.8386586701473899 Test: 0.8150941971800247
# Alpha: 3 Train: 0.8331787754759141 Test: 0.8159840565359215
# Alpha: 4 Train: 0.8289514294906636 Test: 0.8164074943595502
# Alpha: 5 Train: 0.8256180508343482 Test: 0.816615553613196
# Alpha: 6 Train: 0.8229200327711995 Test: 0.8167081125220703
# Alpha: 7 Train: 0.8206835478568135 Test: 0.8167319499278247
# Alpha: 8 Train: 0.8187910786049764 Test: 0.816711806804251
# Alpha: 9 Train: 0.81716139576924 Test: 0.8166620492139389
# Alpha: 10 Train: 0.8157369315054893 Test: 0.8165916480922776
# Alpha: 11 Train: 0.8144758945344523 Test: 0.8165065334035883
# Alpha: 12 Train: 0.8133472709742817 Test: 0.8164108037537479
# Alpha: 13 Train: 0.8123275834727067 Test: 0.8163073927640299
# Alpha: 14 Train: 0.811398740298779 Test: 0.8161984585221332
# Alpha: 15 Train: 0.8105465750879645 Test: 0.8160856229891423
# Alpha: 16 Train: 0.8097598342698181 Test: 0.8159701257011309
# Alpha: 17 Train: 0.8090294611185943 Test: 0.8158529262057428
# Alpha: 18 Train: 0.8083480804274367 Test: 0.8157347745669781
# Alpha: 19 Train: 0.8077096214915773 Test: 0.8156162612575798
# Alpha: 20 Train: 0.8071090381347475 Test: 0.8154978533197708
# Alpha: 21 Train: 0.8065420979376512 Test: 0.8153799211198304
# Alpha: 22 Train: 0.8060052215569339 Test: 0.8152627584989027
# Alpha: 23 Train: 0.8054953588035767 Test: 0.8151465981855341
# Alpha: 24 Train: 0.805009892042787 Test: 0.8150316237424465
# Alpha: 25 Train: 0.804546560141105 Test: 0.8149179789348104
# Alpha: 68 Train: 0.7935657047633161 Test: 0.8114256325321187
# Alpha: 69 Train: 0.7934075257077651 Test: 0.8113695359789271
# Alpha: 70 Train: 0.7932516206170472 Test: 0.8113142263931472
# Alpha: 71 Train: 0.793097923729077 Test: 0.8112596856890419
# Alpha: 72 Train: 0.7929463721464325 Test: 0.8112058962832015
# Alpha: 73 Train: 0.7927969056711365 Test: 0.8111528410816166
# Alpha: 74 Train: 0.7926494666512202 Test: 0.8111005034667352
# Alpha: 75 Train: 0.7925039998380737 Test: 0.8110488672845542
# Alpha: 76 Train: 0.7923604522536807 Test: 0.8109979168318033
# Alpha: 77 Train: 0.7922187730669288 Test: 0.810947636843262
# Alpha: 78 Train: 0.7920789134782562 Test: 0.8108980124792426
# Alpha: 79 Train: 0.7919408266119671 Test: 0.8108490293132704
# Alpha: 80 Train: 0.7918044674156139 Test: 0.8108006733199822
# Alpha: 81 Train: 0.791669792565894 Test: 0.8107529308632667
# Alpha: 82 Train: 0.7915367603805561 Test: 0.8107057886846536
# Alpha: 83 Train: 0.7914053307358679 Test: 0.810659233891971
# Alpha: 84 Train: 0.7912754649892211 Test: 0.8106132539482731
# Alpha: 85 Train: 0.7911471259064984 Test: 0.8105678366610493
# Alpha: 86 Train: 0.7910202775938515 Test: 0.8105229701717124
# Alpha: 87 Train: 0.7908948854335736 Test: 0.8104786429453759
# Alpha: 88 Train: 0.7907709160237718 Test: 0.8104348437609119
# Alpha: 89 Train: 0.7906483371215767 Test: 0.8103915617012947
# Alpha: 90 Train: 0.7905271175896365 Test: 0.810348786144225
# Alpha: 91 Train: 0.7904072273456741 Test: 0.810306506753034
# Alpha: 92 Train: 0.7902886373148985 Test: 0.8102647134678602
# Alpha: 93 Train: 0.7901713193850745 Test: 0.8102233964970993
# Alpha: 94 Train: 0.7900552463640805 Test: 0.8101825463091152
# Alpha: 95 Train: 0.789940391939785 Test: 0.810142153624215
# Alpha: 96 Train: 0.7898267306420945 Test: 0.8101022094068745
# Alpha: 97 Train: 0.7897142378070307 Test: 0.8100627048582156
# Alpha: 98 Train: 0.7896028895427105 Test: 0.8100236314087206
# Alpha: 99 Train: 0.7894926626971072 Test: 0.8099849807111867

# %%
l2 = Ridge(alpha = 7)
l2.fit(xtrain,ytrain)
l2.score(xtrain,ytrain),l2.score(xtest,ytest)
# Out:
# (0.8206835478568135, 0.8167319499278247)

# %%
l2.coef_
# Out:
# array([  266.1977188 ,   -16.85709704,  -201.01933674, -1044.89341653,
#         -552.15782389,  1550.44483854,  3324.32180586,   396.11106537,
#          568.13304374,   580.05981219,    98.99403264,   110.99560393,
#          278.5815679 ,  -245.4703641 ])

# %% [markdown]
# # **Elastic Net**

# %%
en = ElasticNet(alpha = 1) # default alpha=0.1
en.fit(xtrain,ytrain)
en.score(xtrain,ytrain),en.score(xtest,ytest)
# Out:
# (0.7929948742162123, 0.8112292967447791)

# %%
# We can go for Ridge Regression or Lasso
